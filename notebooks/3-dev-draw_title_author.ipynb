# %%
from PIL import Image, ImageDraw, ImageFont
HEIGHT, WIDTH = 480, 800
MAX_WIDTH_RATIO = 0.8

# %%
font = ImageFont.truetype("../fonts/CormorantGaramond-VariableFont_wght.ttf", 24)
italic_font = ImageFont.truetype("../fonts/CormorantGaramond-Italic-VariableFont_wght.ttf", 28)

font.set_variation_by_axes([500])

# %%
def draw_title_author(title: str, author: int, draw: ImageDraw, display_wh_px: tuple[int, int], xy_offset_px: tuple[int, int], title_font: ImageFont, author_font: ImageFont) -> None:
    # Measure both lines
    title_bbox = draw.textbbox((0, 0), title, font=title_font)
    author_bbox = draw.textbbox((0, 0), author, font=author_font)
    
    title_wh_px = (title_bbox[2] - title_bbox[0], title_bbox[3] - title_bbox[1])
    author_wh_px = (author_bbox[2] - author_bbox[0], author_bbox[3] - author_bbox[1])
    
    # Figure out each line's x-position
    title_x_px = display_wh_px[0] - title_wh_px[0] - xy_offset_px[0]
    author_x_px = display_wh_px[0] - author_wh_px[0] - xy_offset_px[0]
    
    # Figure out each line's y-position
    author_y_px = display_wh_px[1] - author_wh_px[1] - xy_offset_px[1]  # bottom line
    title_y_px = author_y_px - title_wh_px[1]  # line above
    
    # Draw text
    draw.text((title_x_px, title_y_px), title, font=title_font, fill=0)
    draw.text((author_x_px, author_y_px), author, font=author_font, fill=0)

# %%
image = Image.new(mode='L', size=(WIDTH, HEIGHT), color=255)
draw = ImageDraw.Draw(image)
draw_title_author('some tadsfasdfasd fadf ads fdaf dafd itle', '— author', draw, (WIDTH, HEIGHT), (20,20), italic_font, font)

# %%
image
# Out:
# <PIL.Image.Image image mode=L size=800x480>
